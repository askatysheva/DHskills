# %%
sentence = "The cat is on the mat"
letters = list(sentence)
words = sentence.split("a")
print(words)
print(letters)
words = sentence.split()
# Out:
# ['The c', 't is on the m', 't']
# ['T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't']

# %%
more_words = words + ["It", "is", "sleeping", "the", "best thing", "!!!", "\"The Doors\""]
print(more_words)
# Out:
# ['The', 'cat', 'is', 'on', 'the', 'mat', 'It', 'is', 'sleeping', 'the', 'best thing', '!!!', '"The Doors"']

# %%
vowels = ['a', 'o', 'u']
vowels = vowels + ['e', 'i', 'lalala', 'y']
print(vowels)
# Out:
# ['a', 'o', 'u', 'e', 'i', 'lalala', 'y']

# %%
print(vowels[0])
print(vowels[-2])
print(vowels[4])
# Out:
# a
# lalala
# i

# %%
print(vowels[1:])
print(vowels[:-2])
print(vowels[1:3])
print(vowels[0:6])
print(vowels [0:5])
# Out:
# ['o', 'u', 'e', 'i', 'lalala', 'y']
# ['a', 'o', 'u', 'e', 'i']
# ['o', 'u']
# ['a', 'o', 'u', 'e', 'i', 'lalala']
# ['a', 'o', 'u', 'e', 'i']

# %%
vowels.append('æ')
print(vowels)
# Out:
# ['a', 'o', 'u', 'e', 'i', 'lalala', 'y', 'æ']

# %%
new_tuple = ()
print(new_tuple)

siblings = ('brother', 'sister')
print(siblings)

words = tuple(words)
print(words)

letters = tuple(sentence)
print(letters)
# Out:
# ()
# ('brother', 'sister')
# ('The', 'cat', 'is', 'on', 'the', 'mat')
# ('T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't')

# %%
words += siblings
print(words)

big_family = siblings * 3
print(big_family)

a = letters * 8
print(a)

b = words * 6
print(b)

words = tuple()
# Out:
# ('The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister')
# ('brother', 'sister', 'brother', 'sister', 'brother', 'sister')
# ('T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't', 'T', 'h', 'e', ' ', 'c', 'a', 't', ' ', 'i', 's', ' ', 'o', 'n', ' ', 't', 'h', 'e', ' ', 'm', 'a', 't')
# ('The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'The', 'cat', 'is', 'on', 'the', 'mat', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister', 'brother', 'sister')

# %%
siblings = ('brother', "sister")
big_family = siblings * 3
print(sorted(big_family)) #функция в функции епта
# Out:
# ['brother', 'brother', 'brother', 'sister', 'sister', 'sister']

# %%
print(big_family[0])
print(big_family[-1])
# Out:
# brother
# sister

# %%
sentence = "the cat is on the mat"
x = set(sentence.split())
x.add(1)
animals = set(['cat', 'dog', 'elephant', 'crocodile', 'fox', 'cat', 'elephant'])
print(x)
print(animals)
# Out:
# {1, 'is', 'on', 'cat', 'the', 'mat'}
# {'crocodile', 'cat', 'elephant', 'fox', 'dog'}

# %%
letters = set(sentence)
print(letters)
# Out:
# {'c', 'e', 'a', 'i', ' ', 'o', 't', 'h', 'n', 's', 'm'}

# %%
animals.add('tiger')
print(animals)
# Out:
# {'crocodile', 'cat', 'tiger', 'elephant', 'fox', 'dog'}

# %%
sentence = "the cat is on the mat"
print(len(sentence))

words = sentence.split()
print(words)

print(len(words))
# Out:
# 21
# ['the', 'cat', 'is', 'on', 'the', 'mat']
# 6

# %%
print("the cat is on the mat".count("the"))
print('the cat is on the mat cat cat'.count("cat"))
# Out:
# 2
# 3

# %%
poem = """живут на земле
существа неземной красоты.
 я думаю, ты догадался,
 что это - коты.
 (да, кошки - хорошее слово, 
 научное слово, но ты,
 читатель, забудь это слово
 и помни лишь слово коты!)
 коты грациозны -
 какая гимнастка
 сравнится с котом?
 взгляни, например,
 как он лижет себя под хвостом!
 коты музыкальны -
 не верь, о читатель,
 пустым разговорам,
 что будто кошачий концерт
 не сравнится с ангельским хором...
 а впрочем, коты
 не боятся людской клеветы.
 коты - они выше мирской суеты.
 поверь, словно светоч среди темноты,
 нам посланы свыше коты!..
 но тот, кто не хочет
 (а ты ведь не хочешь?)
 с котами расстаться,
 тот должен серьёзно
 (да, очень серьёзно!)
 с котами считаться.
 наука открыла:
 природа не можеть терпеть пустоты.
  добавлю: особенно -
 лучшая часть этой самой природы -
 коты.
 держать на голодном пайке?
 говорят,
 можно так обращаться с людьми...
 но если ты держишь котов,
 то корми, и корми, и корми!
 коты в нашем доме
 покой и уют создают, -
 но сами коты
 тоже любят покой и уют!
 и если, допустим,
 внезапно захочешь
 ударить в тамтам,
 сначала подумай,
 приятно ли это котам!
 а главное - даже не пробуй
 к котам обращаться "на ты",
 поскольку любой,
 самый маленький кот -
 это тоже коты!
 советую не забывать,
 что коты -
 несомненные родичи тигров,
 и помнить народную мудрость
 (её я вынес в эпиграф).
  осталось добавить,
 что тех, кто не хочет
 серьёзно считаться с котами,
 коты (и вполне справедливо!)
 считают скотами!"""
print(poem)
# Out:
# живут на земле
# существа неземной красоты.
#  я думаю, ты догадался,
#  что это - коты.
#  (да, кошки - хорошее слово,
#  научное слово, но ты,
#  читатель, забудь это слово
#  и помни лишь слово коты!)
#  коты грациозны -
#  какая гимнастка
#  сравнится с котом?
#  взгляни, например,
#  как он лижет себя под хвостом!
#  коты музыкальны -
#  не верь, о читатель,
#  пустым разговорам,
#  что будто кошачий концерт
#  не сравнится с ангельским хором...
#  а впрочем, коты
#  не боятся людской клеветы.
#  коты - они выше мирской суеты.
#  поверь, словно светоч среди темноты,
#  нам посланы свыше коты!..
#  но тот, кто не хочет
#  (а ты ведь не хочешь?)
#  с котами расстаться,
#  тот должен серьёзно
#  (да, очень серьёзно!)
#  с котами считаться.
#  наука открыла:
#  природа не можеть терпеть пустоты.
#   добавлю: особенно -
#  лучшая часть этой самой природы -
#  коты.
#  держать на голодном пайке?
#  говорят,
#  можно так обращаться с людьми...
#  но если ты держишь котов,
#  то корми, и корми, и корми!
#  коты в нашем доме
#  покой и уют создают, -
#  но сами коты
#  тоже любят покой и уют!
#  и если, допустим,
#  внезапно захочешь
#  ударить в тамтам,
#  сначала подумай,
#  приятно ли это котам!
#  а главное - даже не пробуй
#  к котам обращаться "на ты",
#  поскольку любой,
#  самый маленький кот -
#  это тоже коты!
#  советую не забывать,
#  что коты -
#  несомненные родичи тигров,
#  и помнить народную мудрость
#  (её я вынес в эпиграф).
#   осталось добавить,
#  что тех, кто не хочет
#  серьёзно считаться с котами,
#  коты (и вполне справедливо!)
#  считают скотами!

# %%
probely = poem.split()
print(probely)
# Out:
# ['живут', 'на', 'земле', 'существа', 'неземной', 'красоты.', 'я', 'думаю,', 'ты', 'догадался,', 'что', 'это', '-', 'коты.', '(да,', 'кошки', '-', 'хорошее', 'слово,', 'научное', 'слово,', 'но', 'ты,', 'читатель,', 'забудь', 'это', 'слово', 'и', 'помни', 'лишь', 'слово', 'коты!)', 'коты', 'грациозны', '-', 'какая', 'гимнастка', 'сравнится', 'с', 'котом?', 'взгляни,', 'например,', 'как', 'он', 'лижет', 'себя', 'под', 'хвостом!', 'коты', 'музыкальны', '-', 'не', 'верь,', 'о', 'читатель,', 'пустым', 'разговорам,', 'что', 'будто', 'кошачий', 'концерт', 'не', 'сравнится', 'с', 'ангельским', 'хором...', 'а', 'впрочем,', 'коты', 'не', 'боятся', 'людской', 'клеветы.', 'коты', '-', 'они', 'выше', 'мирской', 'суеты.', 'поверь,', 'словно', 'светоч', 'среди', 'темноты,', 'нам', 'посланы', 'свыше', 'коты!..', 'но', 'тот,', 'кто', 'не', 'хочет', '(а', 'ты', 'ведь', 'не', 'хочешь?)', 'с', 'котами', 'расстаться,', 'тот', 'должен', 'серьёзно', '(да,', 'очень', 'серьёзно!)', 'с', 'котами', 'считаться.', 'наука', 'открыла:', 'природа', 'не', 'можеть', 'терпеть', 'пустоты.', 'добавлю:', 'особенно', '-', 'лучшая', 'часть', 'этой', 'самой', 'природы', '-', 'коты.', 'держать', 'на', 'голодном', 'пайке?', 'говорят,', 'можно', 'так', 'обращаться', 'с', 'людьми...', 'но', 'если', 'ты', 'держишь', 'котов,', 'то', 'корми,', 'и', 'корми,', 'и', 'корми!', 'коты', 'в', 'нашем', 'доме', 'покой', 'и', 'уют', 'создают,', '-', 'но', 'сами', 'коты', 'тоже', 'любят', 'покой', 'и', 'уют!', 'и', 'если,', 'допустим,', 'внезапно', 'захочешь', 'ударить', 'в', 'тамтам,', 'сначала', 'подумай,', 'приятно', 'ли', 'это', 'котам!', 'а', 'главное', '-', 'даже', 'не', 'пробуй', 'к', 'котам', 'обращаться', '"на', 'ты",', 'поскольку', 'любой,', 'самый', 'маленький', 'кот', '-', 'это', 'тоже', 'коты!', 'советую', 'не', 'забывать,', 'что', 'коты', '-', 'несомненные', 'родичи', 'тигров,', 'и', 'помнить', 'народную', 'мудрость', '(её', 'я', 'вынес', 'в', 'эпиграф).', 'осталось', 'добавить,', 'что', 'тех,', 'кто', 'не', 'хочет', 'серьёзно', 'считаться', 'с', 'котами,', 'коты', '(и', 'вполне', 'справедливо!)', 'считают', 'скотами!']

# %%
print(len(probely))
# Out:
# 234

# %%
print(set(probely))
# Out:
# {'помни', 'ты,', 'коты', 'суеты.', 'поверь,', 'нашем', 'осталось', 'например,', 'научное', 'природа', 'людской', 'догадался,', 'расстаться,', 'котов,', 'кошки', 'он', 'считаться', 'сами', 'неземной', 'кто', 'тот', 'светоч', 'они', 'читатель,', 'даже', 'боятся', 'я', 'держишь', 'серьёзно!)', 'думаю,', 'среди', 'тамтам,', 'котами,', 'хорошее', 'голодном', 'котом?', 'уют', 'добавить,', 'вынес', 'гимнастка', 'котами', 'подумай,', 'считают', 'свыше', 'лучшая', 'держать', 'забывать,', 'клеветы.', '(и', 'выше', 'о', 'открыла:', 'хочет', 'красоты.', 'можеть', 'верь,', 'уют!', 'живут', 'корми,', '"на', 'считаться.', 'людьми...', 'внезапно', 'народную', 'кот', 'помнить', 'пустоты.', 'часть', 'справедливо!)', 'взгляни,', 'главное', 'эпиграф).', 'существа', 'но', 'ангельским', 'если,', 'коты!', 'приятно', 'мирской', 'как', 'должен', 'несомненные', 'тот,', 'так', 'пробуй', 'любой,', 'можно', 'темноты,', 'хочешь?)', 'покой', 'родичи', 'ли', 'допустим,', 'пайке?', 'обращаться', 'будто', '(а', 'наука', 'доме', 'и', 'котам', 'на', 'не', 'скотами!', 'лишь', 'самой', 'мудрость', '(её', 'нам', 'маленький', 'впрочем,', 'любят', 'очень', 'грациозны', '-', 'тоже', 'словно', 'говорят,', 'с', 'посланы', 'создают,', 'сравнится', 'слово,', 'советую', 'вполне', 'что', 'слово', 'лижет', 'сначала', 'поскольку', 'корми!', 'ведь', 'ты', 'самый', 'тех,', 'серьёзно', 'если', 'забудь', 'в', 'особенно', 'ударить', 'коты!)', 'то', 'к', 'а', 'этой', 'пустым', 'коты.', 'концерт', 'добавлю:', 'котам!', 'какая', 'хором...', 'земле', 'терпеть', 'кошачий', 'музыкальны', 'захочешь', 'тигров,', '(да,', 'под', 'это', 'разговорам,', 'природы', 'коты!..', 'ты",', 'себя', 'хвостом!'}

# %%
print((poem).count("коты"))
# Out:
# 13

# %%
print((probely).count("коты"))
# Out:
# 8

# %%
len(poem.split("\n"))
# Out:
# 63

# %%
from string import punctuation
print(punctuation)

probely = [w.strip(punctuation) for w in probely]
print(probely)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# ['живут', 'на', 'земле', 'существа', 'неземной', 'красоты', 'я', 'думаю', 'ты', 'догадался', 'что', 'это', '', 'коты', 'да', 'кошки', '', 'хорошее', 'слово', 'научное', 'слово', 'но', 'ты', 'читатель', 'забудь', 'это', 'слово', 'и', 'помни', 'лишь', 'слово', 'коты', 'коты', 'грациозны', '', 'какая', 'гимнастка', 'сравнится', 'с', 'котом', 'взгляни', 'например', 'как', 'он', 'лижет', 'себя', 'под', 'хвостом', 'коты', 'музыкальны', '', 'не', 'верь', 'о', 'читатель', 'пустым', 'разговорам', 'что', 'будто', 'кошачий', 'концерт', 'не', 'сравнится', 'с', 'ангельским', 'хором', 'а', 'впрочем', 'коты', 'не', 'боятся', 'людской', 'клеветы', 'коты', '', 'они', 'выше', 'мирской', 'суеты', 'поверь', 'словно', 'светоч', 'среди', 'темноты', 'нам', 'посланы', 'свыше', 'коты', 'но', 'тот', 'кто', 'не', 'хочет', 'а', 'ты', 'ведь', 'не', 'хочешь', 'с', 'котами', 'расстаться', 'тот', 'должен', 'серьёзно', 'да', 'очень', 'серьёзно', 'с', 'котами', 'считаться', 'наука', 'открыла', 'природа', 'не', 'можеть', 'терпеть', 'пустоты', 'добавлю', 'особенно', '', 'лучшая', 'часть', 'этой', 'самой', 'природы', '', 'коты', 'держать', 'на', 'голодном', 'пайке', 'говорят', 'можно', 'так', 'обращаться', 'с', 'людьми', 'но', 'если', 'ты', 'держишь', 'котов', 'то', 'корми', 'и', 'корми', 'и', 'корми', 'коты', 'в', 'нашем', 'доме', 'покой', 'и', 'уют', 'создают', '', 'но', 'сами', 'коты', 'тоже', 'любят', 'покой', 'и', 'уют', 'и', 'если', 'допустим', 'внезапно', 'захочешь', 'ударить', 'в', 'тамтам', 'сначала', 'подумай', 'приятно', 'ли', 'это', 'котам', 'а', 'главное', '', 'даже', 'не', 'пробуй', 'к', 'котам', 'обращаться', 'на', 'ты', 'поскольку', 'любой', 'самый', 'маленький', 'кот', '', 'это', 'тоже', 'коты', 'советую', 'не', 'забывать', 'что', 'коты', '', 'несомненные', 'родичи', 'тигров', 'и', 'помнить', 'народную', 'мудрость', 'её', 'я', 'вынес', 'в', 'эпиграф', 'осталось', 'добавить', 'что', 'тех', 'кто', 'не', 'хочет', 'серьёзно', 'считаться', 'с', 'котами', 'коты', 'и', 'вполне', 'справедливо', 'считают', 'скотами']

# %%
year = input("Введите ваш год рождения\n")
# Out:
# Введите ваш год рождения
# 1997

# %%
if len(year) != 4:
    print ("Введено неверное число")
else:
    year = int(year)
    if year <=0:
        print("Вы родились до нашей эры?")
    elif year > 0 and year < 1900:
        print: ("Вы родились до XX века?")
    elif year >2010:
        print("Как рано вы научились пользоваться компьютером!")
    else:
        age = 2017 - year
        print("К началу 2018 года вам было", age)
# Out:
# К началу 2018 года вам было 20

# %%
if "cat" not in "cats are fantastic":
    print("How is it possible?!")
else:
    print("Hurray!")
# Out:
# Hurray!

# %%
new_word = input("Введите ваше любимое слово\n")

if  new_word not in probely:
    probely.append(new_word)
    print("Слово", new_word, "добавлено")
else:
    already_exist = probely.count(new_word)
    print("Слово \"" , new_word, "\" встречается", already_exist, "раз")
# Out:
# Введите ваше любимое слово
# коты
# Слово " коты " встречается 15 раз
